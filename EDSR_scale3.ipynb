# %% [markdown]
# ## Import

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
# os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
import prepare_sub_image as ps
import cv2
import numpy as np
from skimage import measure
import PIL.Image as pilimg
import matplotlib.pyplot as plt
import math
from scipy import io
from collections import defaultdict

# %% [markdown]
# ## Metrics

# %%
def ssim(target, ref):
    target_data = np.array(target)
    ref_data = np.array(ref)
    
    (score, diff) = measure.compare_ssim(target_data, ref_data, full = True, multichannel=True)
    
    return score

def psnr(target, ref):
    
    target_data = np.array(target, dtype = float)
    ref_data = np.array(ref, dtype = float)
    
    diff = ref_data - target_data
    diff = diff.flatten('C')
    
    rmse = math.sqrt(np.mean(diff**2))
    
    return 20 * math.log10(255/rmse)

# %% [markdown]
# ## Model

# %%
rgb_mean = np.array([0.4488, 0.4371, 0.4040])


def res_block(x, filters, i):
    
    input_img = x
    
    x = layers.Conv2D(filters = filters, kernel_size = 3, padding = 'same',
                      bias_initializer = 'zeros', name = 'Conv1_resi_{}'.format(i))(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters = filters, kernel_size = 3, padding = 'same', 
                       bias_initializer = 'zeros', name = 'Conv2_resi_{}'.format(i))(x)
    
    if filters == 256:
        res_scale = 0.1
    else:
        res_scale = 1.0
        
    x = layers.Lambda(lambda x: x * res_scale)(x)
    
    x = layers.add([x, input_img])
    
    
    return x

    
def EDSR(scale, input_image, n_feats, n_resblocks):
    
    input_img = input_image
    x = layers.Lambda(lambda x: (x - rgb_mean))(input_image)
    
    x = layers.Conv2D(filters = n_feats, kernel_size = (3,3), padding = 'same', 
                         bias_initializer = 'zeros', name = 'Conv_out_1')(x)
    x_Conv1 = x
    
    for i in range(n_resblocks):
        x = res_block(x = x, filters = n_feats, i = i)
    
    x = layers.Conv2D(filters = n_feats, kernel_size = (3,3), padding = 'same', 
                         bias_initializer = 'zeros', name = 'Conv_out_2')(x)
    x = layers.add([x_Conv1, x])
    
    x = layers.Conv2D(filters = n_feats * (scale ** 2), kernel_size = (3,3), padding = 'same',
                     bias_initializer = 'zeros', name = 'Pixel_shuffle_scale3')(x)
    x = layers.Lambda(lambda x: tf.nn.depth_to_space(x, scale))(x)
    x = layers.Conv2D(filters = 3, kernel_size = (3,3), padding = 'same',
                        bias_initializer = 'zeros', name = 'Conv_out_3')(x)
    
    x = layers.Lambda(lambda x: x + rgb_mean)(x)
    
    EDSR = Model(inputs = input_img, outputs = x)
    
    EDSR.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'mean_absolute_error', metrics = ['mean_absolute_error'])
    
    return EDSR

# %% [markdown]
# ## Train & Predict

# %%
scale = 3
test_set = 'Set5'
conv_side = 8
#total_history = defaultdict(list)

def train():
    
    in1 = layers.Input(shape = (None, None, 3))
    edsr_model = EDSR(scale = scale, input_image = in1, n_feats = 256, n_resblocks = 32)
    
    print(edsr_model.summary())
    
    #edsr_model.load_weights('checkpoint/EDSR_checkpoint_scale2.h5', by_name = True)
    edsr_model.load_weights('checkpoint/EDSR_checkpoint_scale3.h5')
    
    '''
    data, label = ps.read_training_data('training_sample/train_DIV2Kaug_scale3_merge_2.h5')
    val_data, val_label = ps.read_training_data('training_sample/cross_val_DIV2K_scale3.h5')
    '''
    
    PATH_image = 'test_sample/test_mat/{}/scale{}/'.format(test_set, scale)
    IMAGE_PATH = 'output_image/{}/scale{}'.format(test_set, scale)
    
    names_image = os.listdir(PATH_image)
    names_image = sorted(names_image)
    
    nums = len(names_image)
    
    count = 0
    global total_history
    
    checkpoint_filepath = 'checkpoint/EDSR_checkpoint_scale3_merge.h5'
    checkpoint_callbacks = [ModelCheckpoint(filepath = checkpoint_filepath, monitor = 'val_loss', verbose = 1, mode = 'min', 
                                            save_best_only = True)]
    
    for i in range(0, 1):
        
        '''
        edsr_model.fit(x = data, y = label, batch_size = 16, epochs = 2, verbose = 1,
                       callbacks = checkpoint_callbacks, validation_data = (val_data, val_label), shuffle = True)
        '''
        
        count += 1
        
        psnr_edsr = []
        psnr_bicubic = []
        ssim_edsr = []
        ssim_bicubic = []
        
        for i in range(nums):
            
            mat_image = io.loadmat(PATH_image + names_image[i])
            
            hr_img = mat_image['im_hr_rgb']
            bicubic_img = mat_image['im_bicubic_rgb']
            lr_img = mat_image['im_lr_rgb']
            
            INPUT_NAME = IMAGE_PATH + '/' + 'input{}.jpg'.format(i)
            OUTPUT_NAME = IMAGE_PATH + '/' + 'predict{}.jpg'.format(i)
            

            input_shape = lr_img.shape
            
            input_RGB = np.zeros([1, input_shape[0], input_shape[1], 3])
            input_RGB[0, :, :, :] = lr_img / 255
                
            pre = edsr_model.predict(input_RGB, batch_size = 1)
            pre = pre * 255
            pre[pre[:] > 255] = 255
            pre[pre[:] < 0] = 0            
            
            output_shape = hr_img.shape
            
            output_img = np.zeros([output_shape[0], output_shape[1], 3])
            output_img[:, :, 2] = pre[0, :, :, 0]
            output_img[:, :, 1] = pre[0, :, :, 1]
            output_img[:, :, 0] = pre[0, :, :, 2]
            
            cv2.imwrite(OUTPUT_NAME, output_img)
            
            hr_img_r = hr_img[:, :, 0]
            hr_img_g = hr_img[:, :, 1]
            hr_img_b = hr_img[:, :, 2]

            bicubic_img_r = bicubic_img[:, :, 0]
            bicubic_img_g = bicubic_img[:, :, 1]
            bicubic_img_b = bicubic_img[:, :, 2]
            
            output_img_r = output_img[:, :, 2]
            output_img_g = output_img[:, :, 1]
            output_img_b = output_img[:, :, 0]

            hr_img_Y = 16 + (65.738 * hr_img_r + 129.057 * hr_img_g + 25.064 * hr_img_b) / 255
            bicubic_img_Y = 16 + (65.738 * bicubic_img_r + 129.057 * bicubic_img_g + 25.064 * bicubic_img_b) / 255
            output_img_Y = 16 + (65.738 * output_img_r + 129.057 * output_img_g + 25.064 * output_img_b) / 255
                
            
            hr_img_measure = hr_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            bicubic_img_measure = bicubic_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            output_img_measure = output_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            
            
            psnr_bicubic_one = psnr(bicubic_img_measure, hr_img_measure)
            psnr_edsr_one = psnr(output_img_measure, hr_img_measure)
            
            ssim_bicubic_one = ssim(bicubic_img_measure, hr_img_measure)
            ssim_edsr_one = ssim(output_img_measure, hr_img_measure)
            
            print(i+1)
            print('BICUBIC: ', psnr_bicubic_one, 'ssim: ', ssim_bicubic_one)
            print('EDSR: ', psnr_edsr_one, 'ssim: ', ssim_edsr_one)
            
            psnr_bicubic.append(psnr_bicubic_one)
            ssim_bicubic.append(ssim_bicubic_one)
            
            psnr_edsr.append(psnr_edsr_one)
            ssim_edsr.append(ssim_edsr_one)
            
            
        psnr_bicubic_final = np.mean(psnr_bicubic)
        ssim_bicubic_final = np.mean(ssim_bicubic)
        
        psnr_edsr_final = np.mean(psnr_edsr)
        ssim_edsr_final = np.mean(ssim_edsr)
        
        print('Epochs: ', count)
        
        print('Bicubic')
        print('PSNR: ', psnr_bicubic_final, 'SSIM: ', ssim_bicubic_final)
        print('EDSR')
        print('PSNR: ', psnr_edsr_final, 'SSIM: ', ssim_edsr_final)
        
        '''
        for key, value in history.history.items():

            total_history[key] = sum([total_history[key], history.history[key]], [])

            
        length = len(total_history['loss'])

        plt.plot(total_history['loss'])
        plt.plot(total_history['val_loss'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        #plt.xticks(ticks = 1)
        plt.xlim(9, length)
        plt.ylim(0, 0.003)
        plt.legend(['train', 'val'], loc='upper left')
        plt.show()
        '''
    
    
    
if __name__ == '__main__':
    
    train()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, None, None, 3 0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv_out_1 (Conv2D)             (None, None, None, 2 7168        lambda_35[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_0 (Conv2D)           (None, None, None, 2 590080      Conv_out_1[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, None, None, 2 0           Conv1_resi_0[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_0 (Conv2D)           (None, None, None, 2 590080      re_lu_32[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, None, None, 2 0           Conv2_resi_0[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, None, None, 2 0           lambda_36[0][0]
#                                                                  Conv_out_1[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_1 (Conv2D)           (None, None, None, 2 590080      add_33[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, None, None, 2 0           Conv1_resi_1[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_1 (Conv2D)           (None, None, None, 2 590080      re_lu_33[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, None, None, 2 0           Conv2_resi_1[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, None, None, 2 0           lambda_37[0][0]
#                                                                  add_33[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_2 (Conv2D)           (None, None, None, 2 590080      add_34[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, None, None, 2 0           Conv1_resi_2[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_2 (Conv2D)           (None, None, None, 2 590080      re_lu_34[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, None, None, 2 0           Conv2_resi_2[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, None, None, 2 0           lambda_38[0][0]
#                                                                  add_34[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_3 (Conv2D)           (None, None, None, 2 590080      add_35[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, None, None, 2 0           Conv1_resi_3[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_3 (Conv2D)           (None, None, None, 2 590080      re_lu_35[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, None, None, 2 0           Conv2_resi_3[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, None, None, 2 0           lambda_39[0][0]
#                                                                  add_35[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_4 (Conv2D)           (None, None, None, 2 590080      add_36[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, None, None, 2 0           Conv1_resi_4[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_4 (Conv2D)           (None, None, None, 2 590080      re_lu_36[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, None, None, 2 0           Conv2_resi_4[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, None, None, 2 0           lambda_40[0][0]
#                                                                  add_36[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_5 (Conv2D)           (None, None, None, 2 590080      add_37[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, None, None, 2 0           Conv1_resi_5[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_5 (Conv2D)           (None, None, None, 2 590080      re_lu_37[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, None, None, 2 0           Conv2_resi_5[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, None, None, 2 0           lambda_41[0][0]
#                                                                  add_37[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_6 (Conv2D)           (None, None, None, 2 590080      add_38[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, None, None, 2 0           Conv1_resi_6[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_6 (Conv2D)           (None, None, None, 2 590080      re_lu_38[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, None, None, 2 0           Conv2_resi_6[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, None, None, 2 0           lambda_42[0][0]
#                                                                  add_38[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_7 (Conv2D)           (None, None, None, 2 590080      add_39[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, None, None, 2 0           Conv1_resi_7[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_7 (Conv2D)           (None, None, None, 2 590080      re_lu_39[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, None, None, 2 0           Conv2_resi_7[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, None, None, 2 0           lambda_43[0][0]
#                                                                  add_39[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_8 (Conv2D)           (None, None, None, 2 590080      add_40[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, None, None, 2 0           Conv1_resi_8[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_8 (Conv2D)           (None, None, None, 2 590080      re_lu_40[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, None, None, 2 0           Conv2_resi_8[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, None, None, 2 0           lambda_44[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_9 (Conv2D)           (None, None, None, 2 590080      add_41[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, None, None, 2 0           Conv1_resi_9[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_9 (Conv2D)           (None, None, None, 2 590080      re_lu_41[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, None, None, 2 0           Conv2_resi_9[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, None, None, 2 0           lambda_45[0][0]
#                                                                  add_41[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_10 (Conv2D)          (None, None, None, 2 590080      add_42[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, None, None, 2 0           Conv1_resi_10[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_10 (Conv2D)          (None, None, None, 2 590080      re_lu_42[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, None, None, 2 0           Conv2_resi_10[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, None, None, 2 0           lambda_46[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_11 (Conv2D)          (None, None, None, 2 590080      add_43[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, None, None, 2 0           Conv1_resi_11[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_11 (Conv2D)          (None, None, None, 2 590080      re_lu_43[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, None, None, 2 0           Conv2_resi_11[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, None, None, 2 0           lambda_47[0][0]
#                                                                  add_43[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_12 (Conv2D)          (None, None, None, 2 590080      add_44[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, None, None, 2 0           Conv1_resi_12[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_12 (Conv2D)          (None, None, None, 2 590080      re_lu_44[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, None, None, 2 0           Conv2_resi_12[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, None, None, 2 0           lambda_48[0][0]
#                                                                  add_44[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_13 (Conv2D)          (None, None, None, 2 590080      add_45[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, None, None, 2 0           Conv1_resi_13[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_13 (Conv2D)          (None, None, None, 2 590080      re_lu_45[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, None, None, 2 0           Conv2_resi_13[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, None, None, 2 0           lambda_49[0][0]
#                                                                  add_45[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_14 (Conv2D)          (None, None, None, 2 590080      add_46[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, None, None, 2 0           Conv1_resi_14[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_14 (Conv2D)          (None, None, None, 2 590080      re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, None, None, 2 0           Conv2_resi_14[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, None, None, 2 0           lambda_50[0][0]
#                                                                  add_46[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_15 (Conv2D)          (None, None, None, 2 590080      add_47[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, None, None, 2 0           Conv1_resi_15[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_15 (Conv2D)          (None, None, None, 2 590080      re_lu_47[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, None, None, 2 0           Conv2_resi_15[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, None, None, 2 0           lambda_51[0][0]
#                                                                  add_47[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_16 (Conv2D)          (None, None, None, 2 590080      add_48[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, None, None, 2 0           Conv1_resi_16[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_16 (Conv2D)          (None, None, None, 2 590080      re_lu_48[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, None, None, 2 0           Conv2_resi_16[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, None, None, 2 0           lambda_52[0][0]
#                                                                  add_48[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_17 (Conv2D)          (None, None, None, 2 590080      add_49[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, None, None, 2 0           Conv1_resi_17[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_17 (Conv2D)          (None, None, None, 2 590080      re_lu_49[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, None, None, 2 0           Conv2_resi_17[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, None, None, 2 0           lambda_53[0][0]
#                                                                  add_49[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_18 (Conv2D)          (None, None, None, 2 590080      add_50[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, None, None, 2 0           Conv1_resi_18[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_18 (Conv2D)          (None, None, None, 2 590080      re_lu_50[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, None, None, 2 0           Conv2_resi_18[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, None, None, 2 0           lambda_54[0][0]
#                                                                  add_50[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_19 (Conv2D)          (None, None, None, 2 590080      add_51[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, None, None, 2 0           Conv1_resi_19[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_19 (Conv2D)          (None, None, None, 2 590080      re_lu_51[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, None, None, 2 0           Conv2_resi_19[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, None, None, 2 0           lambda_55[0][0]
#                                                                  add_51[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_20 (Conv2D)          (None, None, None, 2 590080      add_52[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, None, None, 2 0           Conv1_resi_20[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_20 (Conv2D)          (None, None, None, 2 590080      re_lu_52[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, None, None, 2 0           Conv2_resi_20[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, None, None, 2 0           lambda_56[0][0]
#                                                                  add_52[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_21 (Conv2D)          (None, None, None, 2 590080      add_53[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, None, None, 2 0           Conv1_resi_21[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_21 (Conv2D)          (None, None, None, 2 590080      re_lu_53[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, None, None, 2 0           Conv2_resi_21[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, None, None, 2 0           lambda_57[0][0]
#                                                                  add_53[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_22 (Conv2D)          (None, None, None, 2 590080      add_54[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, None, None, 2 0           Conv1_resi_22[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_22 (Conv2D)          (None, None, None, 2 590080      re_lu_54[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, None, None, 2 0           Conv2_resi_22[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, None, None, 2 0           lambda_58[0][0]
#                                                                  add_54[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_23 (Conv2D)          (None, None, None, 2 590080      add_55[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, None, None, 2 0           Conv1_resi_23[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_23 (Conv2D)          (None, None, None, 2 590080      re_lu_55[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, None, None, 2 0           Conv2_resi_23[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, None, None, 2 0           lambda_59[0][0]
#                                                                  add_55[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_24 (Conv2D)          (None, None, None, 2 590080      add_56[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, None, None, 2 0           Conv1_resi_24[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_24 (Conv2D)          (None, None, None, 2 590080      re_lu_56[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, None, None, 2 0           Conv2_resi_24[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, None, None, 2 0           lambda_60[0][0]
#                                                                  add_56[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_25 (Conv2D)          (None, None, None, 2 590080      add_57[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, None, None, 2 0           Conv1_resi_25[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_25 (Conv2D)          (None, None, None, 2 590080      re_lu_57[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, None, None, 2 0           Conv2_resi_25[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, None, None, 2 0           lambda_61[0][0]
#                                                                  add_57[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_26 (Conv2D)          (None, None, None, 2 590080      add_58[0][0]
# __________________________________________________________________________________________________
# re_lu_58 (ReLU)                 (None, None, None, 2 0           Conv1_resi_26[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_26 (Conv2D)          (None, None, None, 2 590080      re_lu_58[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, None, None, 2 0           Conv2_resi_26[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, None, None, 2 0           lambda_62[0][0]
#                                                                  add_58[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_27 (Conv2D)          (None, None, None, 2 590080      add_59[0][0]
# __________________________________________________________________________________________________
# re_lu_59 (ReLU)                 (None, None, None, 2 0           Conv1_resi_27[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_27 (Conv2D)          (None, None, None, 2 590080      re_lu_59[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, None, None, 2 0           Conv2_resi_27[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, None, None, 2 0           lambda_63[0][0]
#                                                                  add_59[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_28 (Conv2D)          (None, None, None, 2 590080      add_60[0][0]
# __________________________________________________________________________________________________
# re_lu_60 (ReLU)                 (None, None, None, 2 0           Conv1_resi_28[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_28 (Conv2D)          (None, None, None, 2 590080      re_lu_60[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, None, None, 2 0           Conv2_resi_28[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, None, None, 2 0           lambda_64[0][0]
#                                                                  add_60[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_29 (Conv2D)          (None, None, None, 2 590080      add_61[0][0]
# __________________________________________________________________________________________________
# re_lu_61 (ReLU)                 (None, None, None, 2 0           Conv1_resi_29[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_29 (Conv2D)          (None, None, None, 2 590080      re_lu_61[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, None, None, 2 0           Conv2_resi_29[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, None, None, 2 0           lambda_65[0][0]
#                                                                  add_61[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_30 (Conv2D)          (None, None, None, 2 590080      add_62[0][0]
# __________________________________________________________________________________________________
# re_lu_62 (ReLU)                 (None, None, None, 2 0           Conv1_resi_30[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_30 (Conv2D)          (None, None, None, 2 590080      re_lu_62[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, None, None, 2 0           Conv2_resi_30[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, None, None, 2 0           lambda_66[0][0]
#                                                                  add_62[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_31 (Conv2D)          (None, None, None, 2 590080      add_63[0][0]
# __________________________________________________________________________________________________
# re_lu_63 (ReLU)                 (None, None, None, 2 0           Conv1_resi_31[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_31 (Conv2D)          (None, None, None, 2 590080      re_lu_63[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, None, None, 2 0           Conv2_resi_31[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, None, None, 2 0           lambda_67[0][0]
#                                                                  add_63[0][0]
# __________________________________________________________________________________________________
# Conv_out_2 (Conv2D)             (None, None, None, 2 590080      add_64[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, None, None, 2 0           Conv_out_1[0][0]
#                                                                  Conv_out_2[0][0]
# __________________________________________________________________________________________________
# Pixel_shuffle_scale3 (Conv2D)   (None, None, None, 2 5310720     add_65[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, None, None, 2 0           Pixel_shuffle_scale3[0][0]
# __________________________________________________________________________________________________
# Conv_out_3 (Conv2D)             (None, None, None, 3 6915        lambda_68[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, None, None, 3 0           Conv_out_3[0][0]
# ==================================================================================================
# Total params: 43,680,003
# Trainable params: 43,680,003
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 1
# BICUBIC:  23.17085387286571 ssim:  0.3192125762134446
# EDSR:  24.017377581962695 ssim:  0.4341246645026488
# 2
# BICUBIC:  26.91952260289655 ssim:  0.42220161122367594
# EDSR:  28.84272196782738 ssim:  0.5115314061078513
# 3
# BICUBIC:  29.269052081879046 ssim:  0.5321333125333776
# EDSR:  35.88844365901455 ssim:  0.6199157852212337
# 4
# BICUBIC:  32.42021943316546 ssim:  0.4285421872051292
# EDSR:  35.77877842118617 ssim:  0.49071261141748235
# 5
# BICUBIC:  23.523555891325994 ssim:  0.6177260643728189
# EDSR:  28.602792297429104 ssim:  0.6369312581815307
# 6
# BICUBIC:  26.480814608820722 ssim:  0.61090734015353
# EDSR:  30.336966927453155 ssim:  0.7159351105997438
# 7
# BICUBIC:  26.141630185127166 ssim:  0.44515982395322257
# EDSR:  27.026064420300855 ssim:  0.5244742555486119
# 8
# BICUBIC:  24.404784202008074 ssim:  0.48599396620662794
# EDSR:  25.442559583547148 ssim:  0.5709991355598492
# 9
# BICUBIC:  26.647989853387717 ssim:  0.410123278299995
# EDSR:  27.47603995583091 ssim:  0.504645041710717
# 10
# BICUBIC:  22.97294964288934 ssim:  0.5066362724598318
# EDSR:  25.440231288774633 ssim:  0.6717848131454934
# 11
# BICUBIC:  32.71054907977109 ssim:  0.44710502020901577
# EDSR:  33.99437929042347 ssim:  0.4997829237764964
# 12
# BICUBIC:  27.07602580159741 ssim:  0.4779890721955421
# EDSR:  30.454566762093837 ssim:  0.5953097364719354
# 13
# BICUBIC:  31.92385699211421 ssim:  0.6142558299058279
# EDSR:  36.88505587383478 ssim:  0.6862619067775433
# 14
# BICUBIC:  31.550888686171128 ssim:  0.3758111327484696
# EDSR:  34.162963927737245 ssim:  0.44942929272178817
# Epochs:  1
# Bicubic
# PSNR:  27.515192352429974 SSIM:  0.47812839197717916
# EDSR
# PSNR:  30.310638711243996 SSIM:  0.5651312815530661

# %% [markdown]
# ## Visualization

# %%
def visualization():
    
    hr_img = pilimg.open('test_sample/test_image/{}/hr_ground/butterfly_GT.bmp'.format(test_set))
    pix_hr = np.array(hr_img)
    
    bicubic_img = pilimg.open('test_sample/test_image/{}/bicubic_rgb/scale{}/bicubic_RGB_{}_3.bmp'.format(test_set, scale, scale))
    pix_bicubic = np.array(bicubic_img)
    
    edsr_img = pilimg.open('output_image/{}/scale{}/predict2.jpg'.format(test_set, scale))
    pix_srcnn = np.array(edsr_img)
    
    fig = plt.figure(figsize = (20,32))
    rows = 1
    cols = 3
    
    ax1 = fig.add_subplot(rows, cols, 1)
    ax1.imshow(hr_img)
    ax1.set_title('HR_image', size = 30)
    ax1.axis('off')
    
    ax2 = fig.add_subplot(rows, cols, 2)
    ax2.imshow(bicubic_img)
    ax2.set_title('bicubic_image', size = 30)
    ax2.axis('off')
    
    ax3 = fig.add_subplot(rows, cols, 3)
    ax3.imshow(edsr_img)
    ax3.set_title('EDSR_image', size = 30)
    ax3.axis('off')
    
    plt.show()
    
    
if __name__ == '__main__':
    
    visualization()
