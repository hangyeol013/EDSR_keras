# %% [markdown]
# ## Import

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
import tensorflow as tf
import prepare_sub_image as ps
import cv2
import numpy as np
from skimage import measure
import PIL.Image as pilimg
import matplotlib.pyplot as plt
import math
from scipy import io

# %% [markdown]
# ## Metrics

# %%
def ssim(target, ref):
    target_data = np.array(target)
    ref_data = np.array(ref)
    
    (score, diff) = measure.compare_ssim(target_data, ref_data, full = True, multichannel=True)
    
    return score

def psnr(target, ref):
    
    target_data = np.array(target, dtype = float)
    ref_data = np.array(ref, dtype = float)
    
    diff = ref_data - target_data
    diff = diff.flatten('C')
    
    rmse = math.sqrt(np.mean(diff**2))
    
    return 20 * math.log10(255/rmse)

# %% [markdown]
# ## Model

# %%
rgb_mean = np.array([0.4488, 0.4371, 0.4040])


def res_block(x, filters, i):
    
    input_img = x
    
    x = layers.Conv2D(filters = filters, kernel_size = 3, padding = 'same',
                      bias_initializer = 'zeros', name = 'Conv1_resi_{}'.format(i))(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters = filters, kernel_size = 3, padding = 'same', 
                       bias_initializer = 'zeros', name = 'Conv2_resi_{}'.format(i))(x)
    
    if filters == 256:
        res_scale = 0.1
    else:
        res_scale = 1.0
        
    x = layers.Lambda(lambda x: x * res_scale)(x)
    
    x = layers.add([x, input_img])
    
    
    return x

    
def EDSR(scale, input_image, n_feats, n_resblocks):
    
    input_img = input_image
    x = layers.Lambda(lambda x: (x - rgb_mean))(input_image)
    
    x = layers.Conv2D(filters = n_feats, kernel_size = (3,3), padding = 'same', 
                         bias_initializer = 'zeros', name = 'Conv_out_1')(x)
    x_Conv1 = x
    
    for i in range(n_resblocks):
        x = res_block(x = x, filters = n_feats, i = i)
    
    x = layers.Conv2D(filters = n_feats, kernel_size = (3,3), padding = 'same', 
                         bias_initializer = 'zeros', name = 'Conv_out_2')(x)
    x = layers.add([x_Conv1, x])
    
    x = layers.Conv2D(filters = n_feats * (scale ** 2), kernel_size = (3,3), padding = 'same',
                     bias_initializer = 'zeros')(x)
    x = layers.Lambda(lambda x: tf.nn.depth_to_space(x, scale))(x)
    x = layers.Conv2D(filters = 3, kernel_size = (3,3), padding = 'same',
                        bias_initializer = 'zeros', name = 'Conv_out_3')(x)
    
    x = layers.Lambda(lambda x: x + rgb_mean)(x)
    
    EDSR = Model(inputs = input_img, outputs = x)
    
    EDSR.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'mean_absolute_error', metrics = ['mean_absolute_error'])
    
    return EDSR

# %% [markdown]
# ## Train & Predict

# %%
scale = 2
test_set = 'Urban100'
conv_side = 8

def train():
    
    in1 = layers.Input(shape = (None, None, 3))
    edsr_model = EDSR(scale = scale, input_image = in1, n_feats = 64, n_resblocks = 16)
    
    print(edsr_model.summary())
    
    edsr_model.load_weights('checkpoint/EDSR_checkpoint_baseline_scale2.h5')
    
    '''
    data, label = ps.read_training_data('training_sample/train_DIV2Kaug_scale2_3.h5')
    val_data, val_label = ps.read_training_data('training_sample/cross_val_DIV2K_scale2.h5')
    '''
    
    PATH_image = '../Dataset/test/test_mat/{}/scale{}/'.format(test_set, scale)
    #PATH_image = '/media/idea/ideaHome/mm/HG/SR/Dataset/test/test_mat/{}/scale{}/'.format(test_set, scale)
    IMAGE_PATH = 'output_image/{}/scale{}'.format(test_set, scale)
    
    names_image = os.listdir(PATH_image)
    names_image = sorted(names_image)
    
    nums = len(names_image)
    
    
    count = 0
    
    checkpoint_filepath = 'checkpoint/EDSR_checkpoint_baseline_scale2_pre_3.h5'
    checkpoint_callbacks = [ModelCheckpoint(filepath = checkpoint_filepath, monitor = 'val_loss', verbose = 1, mode = 'min', 
                                            save_best_only = True), 
                            TensorBoard(log_dir = './logs', update_freq = 'epoch', histogram_freq = 1, write_graph = True, 
                                        write_images = True)]
    
    for i in range(0, 1):
        '''
        edsr_model.fit(x = data, y = label, batch_size = 16, epochs = 2, verbose = 1,
                       callbacks = checkpoint_callbacks, validation_data = (val_data, val_label), shuffle = True)
        
        edsr_model.save('model_weight/EDSR_baseline_scale2_pre_3.h5')
        '''
        
        count += 1
        
        psnr_edsr = []
        psnr_bicubic = []
        ssim_edsr = []
        ssim_bicubic = []
        
        for i in range(nums):
            
            mat_image = io.loadmat(PATH_image + names_image[i])
            
            hr_img = mat_image['im_hr_rgb']
            bicubic_img = mat_image['im_bicubic_rgb']
            lr_img = mat_image['im_lr_rgb']
            
            INPUT_NAME = IMAGE_PATH + '/' + 'input{}.jpg'.format(i)
            OUTPUT_NAME = IMAGE_PATH + '/' + 'predict{}.jpg'.format(i)
            

            input_shape = lr_img.shape
            
            input_RGB = np.zeros([1, input_shape[0], input_shape[1], 3])
            input_RGB[0, :, :, :] = lr_img / 255
                
            pre = edsr_model.predict(input_RGB, batch_size = 1)
            pre = pre * 255
            pre[pre[:] > 255] = 255
            pre[pre[:] < 0] = 0            
            
            output_shape = hr_img.shape
            
            # python은 RGB가 아니라 BGR이 default이기 때문
            output_img = np.zeros([output_shape[0], output_shape[1], 3])
            output_img[:, :, 2] = pre[0, :, :, 0]
            output_img[:, :, 1] = pre[0, :, :, 1]
            output_img[:, :, 0] = pre[0, :, :, 2]
            
            cv2.imwrite(OUTPUT_NAME, output_img)
            
            hr_img_r = hr_img[:, :, 0]
            hr_img_g = hr_img[:, :, 1]
            hr_img_b = hr_img[:, :, 2]

            bicubic_img_r = bicubic_img[:, :, 0]
            bicubic_img_g = bicubic_img[:, :, 1]
            bicubic_img_b = bicubic_img[:, :, 2]
            
            # 조심 (위에서 output에 RGB가 아니라 BGR 순서대로 넣었다.)
            output_img_r = output_img[:, :, 2]
            output_img_g = output_img[:, :, 1]
            output_img_b = output_img[:, :, 0]

            hr_img_Y = 16 + (65.738 * hr_img_r + 129.057 * hr_img_g + 25.064 * hr_img_b) / 255
            bicubic_img_Y = 16 + (65.738 * bicubic_img_r + 129.057 * bicubic_img_g + 25.064 * bicubic_img_b) / 255
            output_img_Y = 16 + (65.738 * output_img_r + 129.057 * output_img_g + 25.064 * output_img_b) / 255
                
            
            hr_img_measure = hr_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            bicubic_img_measure = bicubic_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            output_img_measure = output_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            
            
            psnr_bicubic_one = psnr(bicubic_img_measure, hr_img_measure)
            psnr_edsr_one = psnr(output_img_measure, hr_img_measure)
            
            ssim_bicubic_one = ssim(bicubic_img_measure, hr_img_measure)
            ssim_edsr_one = ssim(output_img_measure, hr_img_measure)
            
            print(i+1)
            print('BICUBIC: ', psnr_bicubic_one, 'ssim: ', ssim_bicubic_one)
            print('EDSR: ', psnr_edsr_one, 'ssim: ', ssim_edsr_one)
            
            psnr_bicubic.append(psnr_bicubic_one)
            ssim_bicubic.append(ssim_bicubic_one)
            
            psnr_edsr.append(psnr_edsr_one)
            ssim_edsr.append(ssim_edsr_one)
            
            
        psnr_bicubic_final = np.mean(psnr_bicubic)
        ssim_bicubic_final = np.mean(ssim_bicubic)
        
        psnr_edsr_final = np.mean(psnr_edsr)
        ssim_edsr_final = np.mean(ssim_edsr)
        
        print('Epochs: ', count)
        
        print('Bicubic')
        print('PSNR: ', psnr_bicubic_final, 'SSIM: ', ssim_bicubic_final)
        print('EDSR')
        print('PSNR: ', psnr_edsr_final, 'SSIM: ', ssim_edsr_final)
    
    
    
if __name__ == '__main__':
    
    train()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# Conv_out_1 (Conv2D)             (None, None, None, 6 1792        lambda_38[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_0 (Conv2D)           (None, None, None, 6 36928       Conv_out_1[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, None, None, 6 0           Conv1_resi_0[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_0 (Conv2D)           (None, None, None, 6 36928       re_lu_32[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, None, None, 6 0           Conv2_resi_0[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, None, None, 6 0           lambda_39[0][0]
#                                                                  Conv_out_1[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_1 (Conv2D)           (None, None, None, 6 36928       add_34[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, None, None, 6 0           Conv1_resi_1[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_1 (Conv2D)           (None, None, None, 6 36928       re_lu_33[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, None, None, 6 0           Conv2_resi_1[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, None, None, 6 0           lambda_40[0][0]
#                                                                  add_34[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_2 (Conv2D)           (None, None, None, 6 36928       add_35[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, None, None, 6 0           Conv1_resi_2[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_2 (Conv2D)           (None, None, None, 6 36928       re_lu_34[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, None, None, 6 0           Conv2_resi_2[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, None, None, 6 0           lambda_41[0][0]
#                                                                  add_35[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_3 (Conv2D)           (None, None, None, 6 36928       add_36[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, None, None, 6 0           Conv1_resi_3[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_3 (Conv2D)           (None, None, None, 6 36928       re_lu_35[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, None, None, 6 0           Conv2_resi_3[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, None, None, 6 0           lambda_42[0][0]
#                                                                  add_36[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_4 (Conv2D)           (None, None, None, 6 36928       add_37[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, None, None, 6 0           Conv1_resi_4[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_4 (Conv2D)           (None, None, None, 6 36928       re_lu_36[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, None, None, 6 0           Conv2_resi_4[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, None, None, 6 0           lambda_43[0][0]
#                                                                  add_37[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_5 (Conv2D)           (None, None, None, 6 36928       add_38[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, None, None, 6 0           Conv1_resi_5[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_5 (Conv2D)           (None, None, None, 6 36928       re_lu_37[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, None, None, 6 0           Conv2_resi_5[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, None, None, 6 0           lambda_44[0][0]
#                                                                  add_38[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_6 (Conv2D)           (None, None, None, 6 36928       add_39[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, None, None, 6 0           Conv1_resi_6[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_6 (Conv2D)           (None, None, None, 6 36928       re_lu_38[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, None, None, 6 0           Conv2_resi_6[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, None, None, 6 0           lambda_45[0][0]
#                                                                  add_39[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_7 (Conv2D)           (None, None, None, 6 36928       add_40[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, None, None, 6 0           Conv1_resi_7[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_7 (Conv2D)           (None, None, None, 6 36928       re_lu_39[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, None, None, 6 0           Conv2_resi_7[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, None, None, 6 0           lambda_46[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_8 (Conv2D)           (None, None, None, 6 36928       add_41[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, None, None, 6 0           Conv1_resi_8[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_8 (Conv2D)           (None, None, None, 6 36928       re_lu_40[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, None, None, 6 0           Conv2_resi_8[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, None, None, 6 0           lambda_47[0][0]
#                                                                  add_41[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_9 (Conv2D)           (None, None, None, 6 36928       add_42[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, None, None, 6 0           Conv1_resi_9[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_9 (Conv2D)           (None, None, None, 6 36928       re_lu_41[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, None, None, 6 0           Conv2_resi_9[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, None, None, 6 0           lambda_48[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_10 (Conv2D)          (None, None, None, 6 36928       add_43[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, None, None, 6 0           Conv1_resi_10[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_10 (Conv2D)          (None, None, None, 6 36928       re_lu_42[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, None, None, 6 0           Conv2_resi_10[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, None, None, 6 0           lambda_49[0][0]
#                                                                  add_43[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_11 (Conv2D)          (None, None, None, 6 36928       add_44[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, None, None, 6 0           Conv1_resi_11[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_11 (Conv2D)          (None, None, None, 6 36928       re_lu_43[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, None, None, 6 0           Conv2_resi_11[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, None, None, 6 0           lambda_50[0][0]
#                                                                  add_44[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_12 (Conv2D)          (None, None, None, 6 36928       add_45[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, None, None, 6 0           Conv1_resi_12[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_12 (Conv2D)          (None, None, None, 6 36928       re_lu_44[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, None, None, 6 0           Conv2_resi_12[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, None, None, 6 0           lambda_51[0][0]
#                                                                  add_45[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_13 (Conv2D)          (None, None, None, 6 36928       add_46[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, None, None, 6 0           Conv1_resi_13[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_13 (Conv2D)          (None, None, None, 6 36928       re_lu_45[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, None, None, 6 0           Conv2_resi_13[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, None, None, 6 0           lambda_52[0][0]
#                                                                  add_46[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_14 (Conv2D)          (None, None, None, 6 36928       add_47[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, None, None, 6 0           Conv1_resi_14[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_14 (Conv2D)          (None, None, None, 6 36928       re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, None, None, 6 0           Conv2_resi_14[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, None, None, 6 0           lambda_53[0][0]
#                                                                  add_47[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_15 (Conv2D)          (None, None, None, 6 36928       add_48[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, None, None, 6 0           Conv1_resi_15[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_15 (Conv2D)          (None, None, None, 6 36928       re_lu_47[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, None, None, 6 0           Conv2_resi_15[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, None, None, 6 0           lambda_54[0][0]
#                                                                  add_48[0][0]
# __________________________________________________________________________________________________
# Conv_out_2 (Conv2D)             (None, None, None, 6 36928       add_49[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, None, None, 6 0           Conv_out_1[0][0]
#                                                                  Conv_out_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 2 147712      add_50[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, None, None, 6 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# Conv_out_3 (Conv2D)             (None, None, None, 3 1731        lambda_55[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, None, None, 3 0           Conv_out_3[0][0]
# ==================================================================================================
# Total params: 1,369,859
# Trainable params: 1,369,859
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 1
# BICUBIC:  28.102687796086684 ssim:  0.49838547304996145
# EDSR:  33.22425358457305 ssim:  0.6657193703791704
# 2
# BICUBIC:  26.24987806292785 ssim:  0.50485207329428
# EDSR:  34.473606564823726 ssim:  0.6688383715062721
# 3
# BICUBIC:  25.493408520623454 ssim:  0.5049568083636012
# EDSR:  29.05426220485149 ssim:  0.6617417418987961
# 4
# BICUBIC:  21.33321441432139 ssim:  0.3243681199091301
# EDSR:  29.296060528856867 ssim:  0.46833033134344854
# 5
# BICUBIC:  25.255965214354244 ssim:  0.5957314159074617
# EDSR:  28.376537775657596 ssim:  0.7624322391496668
# 6
# BICUBIC:  30.166561257500607 ssim:  0.6431354475831221
# EDSR:  34.796909034340004 ssim:  0.7708642426023916
# 7
# BICUBIC:  23.08536500679729 ssim:  0.4314414892279589
# EDSR:  25.844263300950104 ssim:  0.6250928666277705
# 8
# BICUBIC:  25.794099909583448 ssim:  0.44519645118633727
# EDSR:  30.946433834495693 ssim:  0.5976410748312279
# 9
# BICUBIC:  29.611758828515093 ssim:  0.6282269757131799
# EDSR:  37.324889390723925 ssim:  0.7449304298373227
# 10
# BICUBIC:  27.14652105048506 ssim:  0.7090641992954173
# EDSR:  31.432609085073516 ssim:  0.8244811604834649
# 11
# BICUBIC:  28.210489191583687 ssim:  0.6785925162714811
# EDSR:  29.703251078871876 ssim:  0.7583303745265709
# 12
# BICUBIC:  22.509670198454323 ssim:  0.514287112736053
# EDSR:  28.10609248631362 ssim:  0.6968700614666096
# 13
# BICUBIC:  27.657566536477646 ssim:  0.6215645639871569
# EDSR:  33.034394779856996 ssim:  0.7765050036374652
# 14
# BICUBIC:  24.22711987595708 ssim:  0.6998063765694277
# EDSR:  27.112405713637322 ssim:  0.8106469325345619
# 15
# BICUBIC:  32.22543707988916 ssim:  0.6771970437464991
# EDSR:  34.68576500189607 ssim:  0.7723326306869506
# 16
# BICUBIC:  27.415109779069837 ssim:  0.4908877611541272
# EDSR:  29.581717939058624 ssim:  0.6230894940722214
# 17
# BICUBIC:  31.391972732818946 ssim:  0.7680241728890411
# EDSR:  37.57999981759977 ssim:  0.873015023535236
# 18
# BICUBIC:  22.088218634927713 ssim:  0.46961424291962073
# EDSR:  25.71001830342333 ssim:  0.6185645345732531
# 19
# BICUBIC:  29.69851561775848 ssim:  0.6228124092597352
# EDSR:  38.14330525894924 ssim:  0.7816531989847783
# 20
# BICUBIC:  27.899865810488286 ssim:  0.21738080037727048
# EDSR:  31.33364489982641 ssim:  0.3595559900437046
# 21
# BICUBIC:  29.243284085136914 ssim:  0.4904412002166707
# EDSR:  32.55844629907695 ssim:  0.6014002857265179
# 22
# BICUBIC:  32.31561420559851 ssim:  0.6622218863408685
# EDSR:  36.925380993530304 ssim:  0.7573209224491596
# 23
# BICUBIC:  25.92589864235121 ssim:  0.605645530428031
# EDSR:  32.808708973216866 ssim:  0.7579168202435485
# 24
# BICUBIC:  24.748198014119637 ssim:  0.5460541748687311
# EDSR:  28.273755316003975 ssim:  0.7048358724090139
# 25
# BICUBIC:  25.488315552279506 ssim:  0.6287376183227078
# EDSR:  31.202394131170017 ssim:  0.8059378243755598
# 26
# BICUBIC:  25.91228842166428 ssim:  0.6108415422731005
# EDSR:  28.702790069828996 ssim:  0.7553928613811746
# 27
# BICUBIC:  29.524443036913883 ssim:  0.6358381480002594
# EDSR:  34.96958991211499 ssim:  0.7653603519445459
# 28
# BICUBIC:  26.995887330354577 ssim:  0.42618517409372614
# EDSR:  32.63321100983326 ssim:  0.6642645420840148
# 29
# BICUBIC:  24.2245387975695 ssim:  0.5395556473808132
# EDSR:  26.452864411692943 ssim:  0.6681939284512147
# 30
# BICUBIC:  28.336664572924715 ssim:  0.4904118439085884
# EDSR:  34.94351928429073 ssim:  0.6805620527039006
# 31
# BICUBIC:  29.42779125567647 ssim:  0.6730545255227626
# EDSR:  35.2774255036106 ssim:  0.7901574376849122
# 32
# BICUBIC:  29.736171239192917 ssim:  0.7154398518563531
# EDSR:  33.8285291460243 ssim:  0.801568842940616
# 33
# BICUBIC:  27.686791964071013 ssim:  0.48506813364179
# EDSR:  31.9833333222155 ssim:  0.6672252338073793
# 34
# BICUBIC:  23.16677240158253 ssim:  0.4373074479385889
# EDSR:  28.608038431315617 ssim:  0.7031108458347123
# 35
# BICUBIC:  26.10241448942432 ssim:  0.7050977519074562
# EDSR:  31.33910807152159 ssim:  0.8296629608597603
# 36
# BICUBIC:  23.620517281185123 ssim:  0.6808698652804258
# EDSR:  35.360845917116414 ssim:  0.9011812589327012
# 37
# BICUBIC:  25.5680350104345 ssim:  0.5333138036088069
# EDSR:  34.506803100096356 ssim:  0.7378500415283911
# 38
# BICUBIC:  29.44896167225496 ssim:  0.7454859900280216
# EDSR:  36.787235705884534 ssim:  0.876009406108398
# 39
# BICUBIC:  26.391399099382284 ssim:  0.6393320113512381
# EDSR:  38.7045014148164 ssim:  0.8094513602938767
# 40
# BICUBIC:  35.02869663587171 ssim:  0.8417711386927347
# EDSR:  39.19181468968056 ssim:  0.9094658835904305
# 41
# BICUBIC:  25.198688312807164 ssim:  0.5206992372271123
# EDSR:  32.98366714693142 ssim:  0.7554562826202709
# 42
# BICUBIC:  25.08953236419498 ssim:  0.5647698643072998
# EDSR:  27.831910222444343 ssim:  0.7130097910647591
# 43
# BICUBIC:  22.865806149343697 ssim:  0.6362106930087186
# EDSR:  27.001898758331965 ssim:  0.8096377558078718
# 44
# BICUBIC:  21.524294468636032 ssim:  0.5429673739101509
# EDSR:  26.356429966669378 ssim:  0.7586302684457734
# 45
# BICUBIC:  24.112009651122 ssim:  0.5835543605843608
# EDSR:  28.875529840827767 ssim:  0.7195550394770968
# 46
# BICUBIC:  28.282228988306844 ssim:  0.5414983367794798
# EDSR:  36.85896288384652 ssim:  0.6841531445103763
# 47
# BICUBIC:  27.12603846062633 ssim:  0.49425020063685815
# EDSR:  30.129175599379494 ssim:  0.6426128519455957
# 48
# BICUBIC:  29.177465279263668 ssim:  0.7296192730753095
# EDSR:  33.47233434875974 ssim:  0.8351784240328461
# 49
# BICUBIC:  27.620122962238792 ssim:  0.6224127905827247
# EDSR:  35.69820140156078 ssim:  0.787476403854929
# 50
# BICUBIC:  23.608055214387463 ssim:  0.6228299099162333
# EDSR:  27.33268963995542 ssim:  0.745052158509196
# 51
# BICUBIC:  22.587809214605365 ssim:  0.4703172380326818
# EDSR:  25.149841785656683 ssim:  0.6125488473944669
# 52
# BICUBIC:  30.52410038892267 ssim:  0.6264518435246539
# EDSR:  37.473629286471855 ssim:  0.7517810550597058
# 53
# BICUBIC:  25.942429394657598 ssim:  0.6145844285646768
# EDSR:  30.574291554983482 ssim:  0.760696627597835
# 54
# BICUBIC:  30.36401521491201 ssim:  0.6728753627640875
# EDSR:  37.92464926485372 ssim:  0.8106319033623108
# 55
# BICUBIC:  27.05171339020523 ssim:  0.7778418522855705
# EDSR:  33.95279449091529 ssim:  0.8956314399007304
# 56
# BICUBIC:  22.672569780367454 ssim:  0.5556834490683894
# EDSR:  28.122544234041964 ssim:  0.7232640515008265
# 57
# BICUBIC:  23.550562736261845 ssim:  0.577480578317423
# EDSR:  25.809628420014445 ssim:  0.7086994073765621
# 58
# BICUBIC:  23.63293998170013 ssim:  0.571301853259563
# EDSR:  25.860404137662535 ssim:  0.7074122736407548
# 59
# BICUBIC:  26.45975228548283 ssim:  0.65982523343215
# EDSR:  29.85533094818581 ssim:  0.8209275674117776
# 60
# BICUBIC:  23.33573441511431 ssim:  0.6832630078920547
# EDSR:  28.182247439404186 ssim:  0.8419149517643169
# 61
# BICUBIC:  22.42949417174533 ssim:  0.3349087627291955
# EDSR:  26.300058541554012 ssim:  0.44359337571813867
# 62
# BICUBIC:  28.80671199834709 ssim:  0.6405261167566562
# EDSR:  31.938847645156745 ssim:  0.7292572323762653
# 63
# BICUBIC:  27.7616694901173 ssim:  0.6347885283265885
# EDSR:  30.938464590997953 ssim:  0.7575956978933588
# 64
# BICUBIC:  23.872194642521194 ssim:  0.506011044029609
# EDSR:  25.56128330746468 ssim:  0.6144922831738888
# 65
# BICUBIC:  20.745521936434997 ssim:  0.655581130276857
# EDSR:  25.21847605999525 ssim:  0.8078109794887537
# 66
# BICUBIC:  31.87725062308772 ssim:  0.6642024874926508
# EDSR:  38.30782341818249 ssim:  0.7831244631467216
# 67
# BICUBIC:  26.237152075298464 ssim:  0.6870606015074373
# EDSR:  29.52202626095058 ssim:  0.813675277768075
# 68
# BICUBIC:  31.476825809521518 ssim:  0.7896281536890377
# EDSR:  36.276863463446794 ssim:  0.8688378539206566
# 69
# BICUBIC:  23.365612952071334 ssim:  0.5403281767931825
# EDSR:  24.75748774769828 ssim:  0.6573666455805085
# 70
# BICUBIC:  28.655126632835717 ssim:  0.5540866881512605
# EDSR:  31.707308909633678 ssim:  0.6902207021110179
# 71
# BICUBIC:  20.303318981862553 ssim:  0.5600198294510291
# EDSR:  26.697744530417545 ssim:  0.7860586316110102
# 72
# BICUBIC:  23.27220572756147 ssim:  0.6312969503654255
# EDSR:  25.692566856231117 ssim:  0.7453968205584511
# 73
# BICUBIC:  24.876930477802013 ssim:  0.5269371491872199
# EDSR:  28.98800409694527 ssim:  0.6982200543895932
# 74
# BICUBIC:  30.595505904914102 ssim:  0.476056256723209
# EDSR:  37.90601605264509 ssim:  0.6415228333454835
# 75
# BICUBIC:  25.933656371863066 ssim:  0.7026135705111608
# EDSR:  30.71207472557883 ssim:  0.8123045277625242
# 76
# BICUBIC:  24.178026655016787 ssim:  0.6041598966419114
# EDSR:  25.86431336436327 ssim:  0.7157174787029132
# 77
# BICUBIC:  29.812723060801414 ssim:  0.6006048843572025
# EDSR:  33.263806329755596 ssim:  0.7341829729943948
# 78
# BICUBIC:  27.070871005394043 ssim:  0.5348527705873485
# EDSR:  29.50100375432937 ssim:  0.6508067217228307
# 79
# BICUBIC:  22.783767211583218 ssim:  0.5848624361856534
# EDSR:  26.579279394657696 ssim:  0.7649551605809535
# 80
# BICUBIC:  36.90968720425872 ssim:  0.6651476248722844
# EDSR:  40.6792582532755 ssim:  0.7599265797635656
# 81
# BICUBIC:  34.13893117091732 ssim:  0.6856179096140148
# EDSR:  44.164664430578696 ssim:  0.7858016599048165
# 82
# BICUBIC:  33.057510931895585 ssim:  0.6589892537099952
# EDSR:  38.933775005723994 ssim:  0.7495207421859139
# 83
# BICUBIC:  23.373192729618772 ssim:  0.4920072875981272
# EDSR:  26.67566226402872 ssim:  0.6693262872897844
# 84
# BICUBIC:  30.668097156155433 ssim:  0.7475627177926913
# EDSR:  34.46547110645345 ssim:  0.8391933662826142
# 85
# BICUBIC:  30.70822442768844 ssim:  0.6550517126200143
# EDSR:  34.42727488569884 ssim:  0.746982527649683
# 86
# BICUBIC:  32.6983609654948 ssim:  0.6652380102575156
# EDSR:  36.628243375163976 ssim:  0.771123466961334
# 87
# BICUBIC:  26.574026571202914 ssim:  0.5704321703530767
# EDSR:  35.04709454476233 ssim:  0.7188091376246643
# 88
# BICUBIC:  21.706471488713206 ssim:  0.5553430147596703
# EDSR:  24.21812080786021 ssim:  0.6987177008953643
# 89
# BICUBIC:  29.053834767687647 ssim:  0.6392665971747741
# EDSR:  31.377287963242164 ssim:  0.762164947307529
# 90
# BICUBIC:  34.89450546136498 ssim:  0.564434897476374
# EDSR:  40.13858313071975 ssim:  0.6804370105107846
# 91
# BICUBIC:  36.401446017390604 ssim:  0.6242928319948037
# EDSR:  45.3732544807755 ssim:  0.7477968632009873
# 92
# BICUBIC:  25.679651808487975 ssim:  0.6702493150120211
# EDSR:  28.776383430175436 ssim:  0.8076431791083869
# 93
# BICUBIC:  18.907104047605262 ssim:  0.32805370707541814
# EDSR:  23.028888563157995 ssim:  0.5901457201357748
# 94
# BICUBIC:  29.358791755957256 ssim:  0.7484523937588807
# EDSR:  37.7285457852637 ssim:  0.8461722071279179
# 95
# BICUBIC:  28.201137743060073 ssim:  0.5784799442920786
# EDSR:  31.33151601458426 ssim:  0.6876289138436684
# 96
# BICUBIC:  21.334409542569233 ssim:  0.503787753537104
# EDSR:  23.666780737253312 ssim:  0.6652065746421232
# 97
# BICUBIC:  25.18512681893874 ssim:  0.505736215449324
# EDSR:  32.26409321087909 ssim:  0.7137841213359818
# 98
# BICUBIC:  26.169186883019215 ssim:  0.5356914316475625
# EDSR:  29.74270309370743 ssim:  0.6643489517493211
# 99
# BICUBIC:  21.999041223386293 ssim:  0.5301645565005187
# EDSR:  24.314193746172347 ssim:  0.6972676996812357
# 100
# BICUBIC:  25.80137647711308 ssim:  0.5922238973606689
# EDSR:  32.43523426902762 ssim:  0.7748737610654037
# Epochs:  1
# Bicubic
# PSNR:  26.82056658801071 SSIM:  0.5895138430289159
# EDSR
# PSNR:  31.65415355806226 SSIM:  0.732237851824611

# %% [markdown]
# ## Visualization

# %%
def visualization():
    
    hr_img = pilimg.open('test_sample/test_image/{}/hr_ground/butterfly_GT.bmp'.format(test_set))
    pix_hr = np.array(hr_img)
    
    bicubic_img = pilimg.open('test_sample/test_image/{}/bicubic_rgb/scale{}/bicubic_RGB_{}_3.bmp'.format(test_set, scale, scale))
    pix_bicubic = np.array(bicubic_img)
    
    edsr_img = pilimg.open('output_image/{}/scale{}/predict2.jpg'.format(test_set, scale))
    pix_srcnn = np.array(edsr_img)
    
    fig = plt.figure(figsize = (20,32))
    rows = 1
    cols = 3
    
    ax1 = fig.add_subplot(rows, cols, 1)
    ax1.imshow(hr_img)
    ax1.set_title('HR_image', size = 30)
    ax1.axis('off')
    
    ax2 = fig.add_subplot(rows, cols, 2)
    ax2.imshow(bicubic_img)
    ax2.set_title('bicubic_image', size = 30)
    ax2.axis('off')
    
    ax3 = fig.add_subplot(rows, cols, 3)
    ax3.imshow(edsr_img)
    ax3.set_title('EDSR_image', size = 30)
    ax3.axis('off')
    
    plt.show()
    
    
if __name__ == '__main__':
    
    visualization()

# %%
PSNR:  33.65739569476097 SSIM:  0.7254005110127355
EDSR
PSNR:  37.81399989848044 SSIM:  0.8039927286077582
