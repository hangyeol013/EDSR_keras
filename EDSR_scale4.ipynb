# %% [markdown]
# ## Import

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
# os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
import prepare_sub_image as ps
import cv2
import numpy as np
from skimage import measure
import PIL.Image as pilimg
import matplotlib.pyplot as plt
import math
from scipy import io
from collections import defaultdict

# %% [markdown]
# ## Metrics

# %%
def ssim(target, ref):
    target_data = np.array(target)
    ref_data = np.array(ref)
    
    (score, diff) = measure.compare_ssim(target_data, ref_data, full = True, multichannel=True)
    
    return score

def psnr(target, ref):
    
    target_data = np.array(target, dtype = float)
    ref_data = np.array(ref, dtype = float)
    
    diff = ref_data - target_data
    diff = diff.flatten('C')
    
    rmse = math.sqrt(np.mean(diff**2))
    
    return 20 * math.log10(255/rmse)

# %% [markdown]
# ## Model

# %%
rgb_mean = np.array([0.4488, 0.4371, 0.4040])


def res_block(x, filters, i):
    
    input_img = x
    
    x = layers.Conv2D(filters = filters, kernel_size = 3, padding = 'same',
                      bias_initializer = 'zeros', name = 'Conv1_resi_{}'.format(i))(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters = filters, kernel_size = 3, padding = 'same', 
                       bias_initializer = 'zeros', name = 'Conv2_resi_{}'.format(i))(x)
    
    if filters == 256:
        res_scale = 0.1
    else:
        res_scale = 1.0
        
    x = layers.Lambda(lambda x: x * res_scale)(x)
    
    x = layers.add([x, input_img])
    
    
    return x

    
def EDSR(scale, input_image, n_feats, n_resblocks):
    
    input_img = input_image
    x = layers.Lambda(lambda x: (x - rgb_mean))(input_image)
    
    x = layers.Conv2D(filters = n_feats, kernel_size = (3,3), padding = 'same', 
                         bias_initializer = 'zeros', name = 'Conv_out_1')(x)
    x_Conv1 = x
    
    for i in range(n_resblocks):
        x = res_block(x = x, filters = n_feats, i = i)
    
    x = layers.Conv2D(filters = n_feats, kernel_size = (3,3), padding = 'same', 
                         bias_initializer = 'zeros', name = 'Conv_out_2')(x)
    x = layers.add([x_Conv1, x])
    
    x = layers.Conv2D(filters = n_feats * (scale ** 2), kernel_size = (3,3), padding = 'same',
                     bias_initializer = 'zeros', name = 'Pixel_shuffle_scale4')(x)
    x = layers.Lambda(lambda x: tf.nn.depth_to_space(x, scale))(x)
    x = layers.Conv2D(filters = 3, kernel_size = (3,3), padding = 'same',
                        bias_initializer = 'zeros', name = 'Conv_out_3')(x)
    
    x = layers.Lambda(lambda x: x + rgb_mean)(x)
    
    EDSR = Model(inputs = input_img, outputs = x)
    
    EDSR.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'mean_absolute_error', metrics = ['mean_absolute_error'])
    
    return EDSR

# %% [markdown]
# ## Train & Predict

# %%
scale = 4
test_set = 'Set5'
conv_side = 8

def train():
    
    in1 = layers.Input(shape = (None, None, 3))
    edsr_model = EDSR(scale = scale, input_image = in1, n_feats = 256, n_resblocks = 32)
    
    print(edsr_model.summary())
    
    #edsr_model.load_weights('checkpoint/EDSR_checkpoint_scale2.h5', by_name = True)
    edsr_model.load_weights('checkpoint/EDSR_checkpoint_scale4.h5')
    
    data, label = ps.read_training_data('training_sample/train_DIV2Kaug_scale4_merge.h5')
    val_data, val_label = ps.read_training_data('training_sample/cross_val_DIV2K_scale4.h5')
    
    
    PATH_image = 'test_sample/test_mat/{}/scale{}/'.format(test_set, scale)
    IMAGE_PATH = 'output_image/{}/scale{}'.format(test_set, scale)
    
    names_image = os.listdir(PATH_image)
    names_image = sorted(names_image)
    
    nums = len(names_image)
    
    count = 0
    global total_history
    
    checkpoint_filepath = 'checkpoint/EDSR_checkpoint_scale4_2.h5'
    checkpoint_callbacks = [ModelCheckpoint(filepath = checkpoint_filepath, monitor = 'val_loss', verbose = 1, mode = 'min', 
                                            save_best_only = True), 
                            TensorBoard(log_dir = './logs', update_freq = 'epoch', histogram_freq = 1, write_graph = True, 
                                        write_images = True)]
    
    for i in range(0, 1):
        
        '''
        edsr_model.fit(x = data, y = label, batch_size = 16, epochs = 2, verbose = 1,
                       callbacks = checkpoint_callbacks, validation_data = (val_data, val_label), shuffle = True)
        '''
        
        count += 1
        
        psnr_edsr = []
        psnr_bicubic = []
        ssim_edsr = []
        ssim_bicubic = []
        
        for i in range(nums):
            
            mat_image = io.loadmat(PATH_image + names_image[i])
            
            hr_img = mat_image['im_hr_rgb']
            bicubic_img = mat_image['im_bicubic_rgb']
            lr_img = mat_image['im_lr_rgb']
            
            INPUT_NAME = IMAGE_PATH + '/' + 'input{}.jpg'.format(i)
            OUTPUT_NAME = IMAGE_PATH + '/' + 'predict{}.jpg'.format(i)
            

            input_shape = lr_img.shape
            
            input_RGB = np.zeros([1, input_shape[0], input_shape[1], 3])
            input_RGB[0, :, :, :] = lr_img / 255
                
            pre = edsr_model.predict(input_RGB, batch_size = 1)
            pre = pre * 255
            pre[pre[:] > 255] = 255
            pre[pre[:] < 0] = 0            
            
            output_shape = hr_img.shape
            
            output_img = np.zeros([output_shape[0], output_shape[1], 3])
            output_img[:, :, 2] = pre[0, :, :, 0]
            output_img[:, :, 1] = pre[0, :, :, 1]
            output_img[:, :, 0] = pre[0, :, :, 2]
            
            cv2.imwrite(OUTPUT_NAME, output_img)
            
            hr_img_r = hr_img[:, :, 0]
            hr_img_g = hr_img[:, :, 1]
            hr_img_b = hr_img[:, :, 2]

            bicubic_img_r = bicubic_img[:, :, 0]
            bicubic_img_g = bicubic_img[:, :, 1]
            bicubic_img_b = bicubic_img[:, :, 2]
            
            output_img_r = output_img[:, :, 2]
            output_img_g = output_img[:, :, 1]
            output_img_b = output_img[:, :, 0]

            hr_img_Y = 16 + (65.738 * hr_img_r + 129.057 * hr_img_g + 25.064 * hr_img_b) / 255
            bicubic_img_Y = 16 + (65.738 * bicubic_img_r + 129.057 * bicubic_img_g + 25.064 * bicubic_img_b) / 255
            output_img_Y = 16 + (65.738 * output_img_r + 129.057 * output_img_g + 25.064 * output_img_b) / 255
                
            
            hr_img_measure = hr_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            bicubic_img_measure = bicubic_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            output_img_measure = output_img_Y[conv_side:-conv_side, conv_side:-conv_side]
            
            
            psnr_bicubic_one = psnr(bicubic_img_measure, hr_img_measure)
            psnr_edsr_one = psnr(output_img_measure, hr_img_measure)
            
            ssim_bicubic_one = ssim(bicubic_img_measure, hr_img_measure)
            ssim_edsr_one = ssim(output_img_measure, hr_img_measure)
            
            print(i+1)
            print('BICUBIC: ', psnr_bicubic_one, 'ssim: ', ssim_bicubic_one)
            print('EDSR: ', psnr_edsr_one, 'ssim: ', ssim_edsr_one)
            
            psnr_bicubic.append(psnr_bicubic_one)
            ssim_bicubic.append(ssim_bicubic_one)
            
            psnr_edsr.append(psnr_edsr_one)
            ssim_edsr.append(ssim_edsr_one)
            
            
        psnr_bicubic_final = np.mean(psnr_bicubic)
        ssim_bicubic_final = np.mean(ssim_bicubic)
        
        psnr_edsr_final = np.mean(psnr_edsr)
        ssim_edsr_final = np.mean(ssim_edsr)
        
        print('Epochs: ', count)
        
        print('Bicubic')
        print('PSNR: ', psnr_bicubic_final, 'SSIM: ', ssim_bicubic_final)
        print('EDSR')
        print('PSNR: ', psnr_edsr_final, 'SSIM: ', ssim_edsr_final)
    
    
        '''
        for key, value in history.history.items():

            total_history[key] = sum([total_history[key], history.history[key]], [])

            
        length = len(total_history['loss'])

        plt.plot(total_history['loss'])
        plt.plot(total_history['val_loss'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        #plt.xticks(ticks = 1)
        plt.xlim(9, length)
        plt.ylim(0, 0.003)
        plt.legend(['train', 'val'], loc='upper left')
        plt.show()
        '''
    
    
if __name__ == '__main__':
    
    train()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv_out_1 (Conv2D)             (None, None, None, 2 7168        lambda[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_0 (Conv2D)           (None, None, None, 2 590080      Conv_out_1[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, None, None, 2 0           Conv1_resi_0[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_0 (Conv2D)           (None, None, None, 2 590080      re_lu[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None, 2 0           Conv2_resi_0[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, None, None, 2 0           lambda_1[0][0]
#                                                                  Conv_out_1[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_1 (Conv2D)           (None, None, None, 2 590080      add[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, None, None, 2 0           Conv1_resi_1[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_1 (Conv2D)           (None, None, None, 2 590080      re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, None, 2 0           Conv2_resi_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           lambda_2[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_2 (Conv2D)           (None, None, None, 2 590080      add_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, None, None, 2 0           Conv1_resi_2[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_2 (Conv2D)           (None, None, None, 2 590080      re_lu_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, None, None, 2 0           Conv2_resi_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           lambda_3[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_3 (Conv2D)           (None, None, None, 2 590080      add_2[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, None, None, 2 0           Conv1_resi_3[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_3 (Conv2D)           (None, None, None, 2 590080      re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, None, None, 2 0           Conv2_resi_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           lambda_4[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_4 (Conv2D)           (None, None, None, 2 590080      add_3[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, None, None, 2 0           Conv1_resi_4[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_4 (Conv2D)           (None, None, None, 2 590080      re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, None, None, 2 0           Conv2_resi_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 2 0           lambda_5[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_5 (Conv2D)           (None, None, None, 2 590080      add_4[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, None, None, 2 0           Conv1_resi_5[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_5 (Conv2D)           (None, None, None, 2 590080      re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, None, None, 2 0           Conv2_resi_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 2 0           lambda_6[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_6 (Conv2D)           (None, None, None, 2 590080      add_5[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, None, None, 2 0           Conv1_resi_6[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_6 (Conv2D)           (None, None, None, 2 590080      re_lu_6[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, None, None, 2 0           Conv2_resi_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 2 0           lambda_7[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_7 (Conv2D)           (None, None, None, 2 590080      add_6[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, None, None, 2 0           Conv1_resi_7[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_7 (Conv2D)           (None, None, None, 2 590080      re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, None, None, 2 0           Conv2_resi_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 2 0           lambda_8[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_8 (Conv2D)           (None, None, None, 2 590080      add_7[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, None, None, 2 0           Conv1_resi_8[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_8 (Conv2D)           (None, None, None, 2 590080      re_lu_8[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, None, None, 2 0           Conv2_resi_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 2 0           lambda_9[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_9 (Conv2D)           (None, None, None, 2 590080      add_8[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, None, None, 2 0           Conv1_resi_9[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_9 (Conv2D)           (None, None, None, 2 590080      re_lu_9[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, None, None, 2 0           Conv2_resi_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 2 0           lambda_10[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_10 (Conv2D)          (None, None, None, 2 590080      add_9[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, None, None, 2 0           Conv1_resi_10[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_10 (Conv2D)          (None, None, None, 2 590080      re_lu_10[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, None, None, 2 0           Conv2_resi_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 2 0           lambda_11[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_11 (Conv2D)          (None, None, None, 2 590080      add_10[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, None, None, 2 0           Conv1_resi_11[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_11 (Conv2D)          (None, None, None, 2 590080      re_lu_11[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, None, None, 2 0           Conv2_resi_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 2 0           lambda_12[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_12 (Conv2D)          (None, None, None, 2 590080      add_11[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, None, None, 2 0           Conv1_resi_12[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_12 (Conv2D)          (None, None, None, 2 590080      re_lu_12[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, None, None, 2 0           Conv2_resi_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 2 0           lambda_13[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_13 (Conv2D)          (None, None, None, 2 590080      add_12[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, None, None, 2 0           Conv1_resi_13[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_13 (Conv2D)          (None, None, None, 2 590080      re_lu_13[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, None, None, 2 0           Conv2_resi_13[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 2 0           lambda_14[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_14 (Conv2D)          (None, None, None, 2 590080      add_13[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, None, None, 2 0           Conv1_resi_14[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_14 (Conv2D)          (None, None, None, 2 590080      re_lu_14[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, None, None, 2 0           Conv2_resi_14[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 2 0           lambda_15[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_15 (Conv2D)          (None, None, None, 2 590080      add_14[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, None, None, 2 0           Conv1_resi_15[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_15 (Conv2D)          (None, None, None, 2 590080      re_lu_15[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, None, None, 2 0           Conv2_resi_15[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 2 0           lambda_16[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_16 (Conv2D)          (None, None, None, 2 590080      add_15[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, None, None, 2 0           Conv1_resi_16[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_16 (Conv2D)          (None, None, None, 2 590080      re_lu_16[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, None, None, 2 0           Conv2_resi_16[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 2 0           lambda_17[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_17 (Conv2D)          (None, None, None, 2 590080      add_16[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, None, None, 2 0           Conv1_resi_17[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_17 (Conv2D)          (None, None, None, 2 590080      re_lu_17[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, None, None, 2 0           Conv2_resi_17[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           lambda_18[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_18 (Conv2D)          (None, None, None, 2 590080      add_17[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, None, None, 2 0           Conv1_resi_18[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_18 (Conv2D)          (None, None, None, 2 590080      re_lu_18[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, None, None, 2 0           Conv2_resi_18[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           lambda_19[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_19 (Conv2D)          (None, None, None, 2 590080      add_18[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, None, None, 2 0           Conv1_resi_19[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_19 (Conv2D)          (None, None, None, 2 590080      re_lu_19[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, None, None, 2 0           Conv2_resi_19[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           lambda_20[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_20 (Conv2D)          (None, None, None, 2 590080      add_19[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, None, None, 2 0           Conv1_resi_20[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_20 (Conv2D)          (None, None, None, 2 590080      re_lu_20[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, None, None, 2 0           Conv2_resi_20[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 2 0           lambda_21[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_21 (Conv2D)          (None, None, None, 2 590080      add_20[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, None, None, 2 0           Conv1_resi_21[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_21 (Conv2D)          (None, None, None, 2 590080      re_lu_21[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, None, None, 2 0           Conv2_resi_21[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 2 0           lambda_22[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_22 (Conv2D)          (None, None, None, 2 590080      add_21[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, None, None, 2 0           Conv1_resi_22[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_22 (Conv2D)          (None, None, None, 2 590080      re_lu_22[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, None, None, 2 0           Conv2_resi_22[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 2 0           lambda_23[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_23 (Conv2D)          (None, None, None, 2 590080      add_22[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, None, None, 2 0           Conv1_resi_23[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_23 (Conv2D)          (None, None, None, 2 590080      re_lu_23[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, None, None, 2 0           Conv2_resi_23[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 2 0           lambda_24[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_24 (Conv2D)          (None, None, None, 2 590080      add_23[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, None, None, 2 0           Conv1_resi_24[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_24 (Conv2D)          (None, None, None, 2 590080      re_lu_24[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, None, None, 2 0           Conv2_resi_24[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 2 0           lambda_25[0][0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_25 (Conv2D)          (None, None, None, 2 590080      add_24[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, None, None, 2 0           Conv1_resi_25[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_25 (Conv2D)          (None, None, None, 2 590080      re_lu_25[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, None, None, 2 0           Conv2_resi_25[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 2 0           lambda_26[0][0]
#                                                                  add_24[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_26 (Conv2D)          (None, None, None, 2 590080      add_25[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, None, None, 2 0           Conv1_resi_26[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_26 (Conv2D)          (None, None, None, 2 590080      re_lu_26[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, None, None, 2 0           Conv2_resi_26[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 2 0           lambda_27[0][0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_27 (Conv2D)          (None, None, None, 2 590080      add_26[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, None, None, 2 0           Conv1_resi_27[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_27 (Conv2D)          (None, None, None, 2 590080      re_lu_27[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, None, None, 2 0           Conv2_resi_27[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 2 0           lambda_28[0][0]
#                                                                  add_26[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_28 (Conv2D)          (None, None, None, 2 590080      add_27[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, None, None, 2 0           Conv1_resi_28[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_28 (Conv2D)          (None, None, None, 2 590080      re_lu_28[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, None, None, 2 0           Conv2_resi_28[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 2 0           lambda_29[0][0]
#                                                                  add_27[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_29 (Conv2D)          (None, None, None, 2 590080      add_28[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, None, None, 2 0           Conv1_resi_29[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_29 (Conv2D)          (None, None, None, 2 590080      re_lu_29[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, None, None, 2 0           Conv2_resi_29[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 2 0           lambda_30[0][0]
#                                                                  add_28[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_30 (Conv2D)          (None, None, None, 2 590080      add_29[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, None, None, 2 0           Conv1_resi_30[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_30 (Conv2D)          (None, None, None, 2 590080      re_lu_30[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, None, None, 2 0           Conv2_resi_30[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, None, None, 2 0           lambda_31[0][0]
#                                                                  add_29[0][0]
# __________________________________________________________________________________________________
# Conv1_resi_31 (Conv2D)          (None, None, None, 2 590080      add_30[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, None, None, 2 0           Conv1_resi_31[0][0]
# __________________________________________________________________________________________________
# Conv2_resi_31 (Conv2D)          (None, None, None, 2 590080      re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, None, None, 2 0           Conv2_resi_31[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, None, None, 2 0           lambda_32[0][0]
#                                                                  add_30[0][0]
# __________________________________________________________________________________________________
# Conv_out_2 (Conv2D)             (None, None, None, 2 590080      add_31[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, None, None, 2 0           Conv_out_1[0][0]
#                                                                  Conv_out_2[0][0]
# __________________________________________________________________________________________________
# Pixel_shuffle_scale4 (Conv2D)   (None, None, None, 4 9441280     add_32[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, None, None, 2 0           Pixel_shuffle_scale4[0][0]
# __________________________________________________________________________________________________
# Conv_out_3 (Conv2D)             (None, None, None, 3 6915        lambda_33[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, None, None, 3 0           Conv_out_3[0][0]
# ==================================================================================================
# Total params: 47,810,563
# Trainable params: 47,810,563
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 32000 samples, validate on 300 samples
# Epoch 1/2
#    96/32000 [..............................] - ETA: 18:19:01 - loss: 0.3139 - mean_absolute_error: 0.3139

# %% [markdown]
# ## Visualization

# %%
def visualization():
    
    hr_img = pilimg.open('test_sample/test_image/{}/hr_ground/butterfly_GT.bmp'.format(test_set))
    pix_hr = np.array(hr_img)
    
    bicubic_img = pilimg.open('test_sample/test_image/{}/bicubic_rgb/scale{}/bicubic_RGB_{}_3.bmp'.format(test_set, scale, scale))
    pix_bicubic = np.array(bicubic_img)
    
    vdsr_img = pilimg.open('output_image/{}/scale{}/predict2.jpg'.format(test_set, scale))
    pix_srcnn = np.array(vdsr_img)
    
    fig = plt.figure(figsize = (20,32))
    rows = 1
    cols = 3
    
    ax1 = fig.add_subplot(rows, cols, 1)
    ax1.imshow(hr_img)
    ax1.set_title('HR_image', size = 30)
    ax1.axis('off')
    
    ax2 = fig.add_subplot(rows, cols, 2)
    ax2.imshow(bicubic_img)
    ax2.set_title('bicubic_image', size = 30)
    ax2.axis('off')
    
    ax3 = fig.add_subplot(rows, cols, 3)
    ax3.imshow(vdsr_img)
    ax3.set_title('VDSR_image', size = 30)
    ax3.axis('off')
    
    plt.show()
    
    
if __name__ == '__main__':
    
    visualization()
